# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('sales_data_with_discounts.csv')
df
# Out:
#            Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# ...

# %%
#displaying only numerical cols
num_cols = df.select_dtypes(include=np.number)
print(num_cols.columns)
# Out:
# Index(['Volume', 'Avg Price', 'Total Sales Value', 'Discount Rate (%)',
#        'Discount Amount', 'Net Sales Value'],
#       dtype='object')

# %%
# Mean
mean_values = num_cols.mean()

# Median
median_values = num_cols.median()

# Mode
mode_values = num_cols.mode().iloc[0]

# Standard Deviation
std_values = num_cols.std()

# Combine into one table
stats_summary = pd.DataFrame({
    "Mean": mean_values,
    "Median": median_values,
    "Mode": mode_values,
    "Standard Deviation": std_values
})

print(stats_summary)
# Out:
#                            Mean       Median          Mode  Standard Deviation
# Volume                 5.066667     4.000000      3.000000            4.231602
# Avg Price          10453.433333  1450.000000    400.000000        18079.904840
# Total Sales Value  33812.835556  5700.000000  24300.000000        50535.074173
# Discount Rate (%)     15.155242    16.577766      5.007822            4.220602
# Discount Amount     3346.499424   988.933733     69.177942         4509.902963
# Net Sales Value    30466.336131  4677.788059    326.974801        46358.656624

# %% [raw]
# # interpretation
# 1️) Mean
#
# Average value of the column.
# Sensitive to outliers.
# If mean is much higher/lower than median = possible skewness.
#
# 2️) Median
#
# Middle value.
# Not affected by outliers.
# Better measure for skewed data (like salary).
#
# 3️) Mode
#
# Most frequently occurring value.
# Useful for categorical data.
# In numeric data, may indicate common value clusters.
#
# 4️) Standard Deviation
#
# Measures spread/dispersion.
# Low std = values are close to mean.
# High std = values widely spread.

# %% [markdown]
# ## Visualization

# %%
## histogram
for col in num_cols:
    sns.histplot(data=df[col], bins=20)
    plt.show()

# %%
## box plot
for col in df.columns:
    sns.boxplot(data=df,y=col)
    plot.show()

# %% [raw]
# As we can see that there are more amount of outliers in numerical columns which usually increases the skewness of the
# data, where outliers capping is must needed to reduce the out liers effect on future predictions

# %%
categorical_cols = df.select_dtypes(include=['object', 'category']).columns

print("Categorical Columns:", list(categorical_cols))

for col in categorical_cols:
    plt.figure(figsize=(6,4))
    sns.countplot(x=col, data=df)
    plt.title(f"Bar Chart of {col}")
    plt.xticks(rotation=45)
    plt.show()

    # Print frequency table
    print(f"\nValue Counts for {col}:")
    print(df[col].value_counts())
# Out:
# Categorical Columns: ['Date', 'Day', 'SKU', 'City', 'BU', 'Brand', 'Model']
# Value Counts for Date:
# Date
# 01-04-2021    30
# 02-04-2021    30
# 03-04-2021    30
# 04-04-2021    30
# 05-04-2021    30
# 06-04-2021    30
# 07-04-2021    30
# 08-04-2021    30
# 09-04-2021    30
# 10-04-2021    30
# 11-04-2021    30
# 12-04-2021    30
# 13-04-2021    30
# 14-04-2021    30
# 15-04-2021    30
# Name: count, dtype: int64
# Value Counts for Day:
# Day
# Thursday     90
# Friday       60
# Saturday     60
# Sunday       60
# Monday       60
# Tuesday      60
# Wednesday    60
# Name: count, dtype: int64
# Value Counts for SKU:
# SKU
# M01    15
# M02    15
# L09    15
# L08    15
# L07    15
# L06    15
# L05    15
# L04    15
# L03    15
# L02    15
# L01    15
# F10    15
# F09    15
# F08    15
# F07    15
# F06    15
# F05    15
# F04    15
# F03    15
# F02    15
# F01    15
# M10    15
# M09    15
# M08    15
# M07    15
# M06    15
# M05    15
# M04    15
# M03    15
# L10    15
# ...

# %% [markdown]
# ## Conclusion

# %% [raw]
# Sales values are highly right-skewed — a few high-value transactions significantly increase the average revenue.
#
# Average discount rate is ~15%, indicating a consistent discount strategy.
#
# Most transactions involve small to medium quantities (average ≈ 5 units), with a few bulk purchases.
#
# Revenue and discount amounts show high variability, suggesting price differences across product categories.
#
# Brand and model distribution is structured and balanced, though some brands appear more frequently.
#
# Only one city is present, so geographical comparison is not possible.
