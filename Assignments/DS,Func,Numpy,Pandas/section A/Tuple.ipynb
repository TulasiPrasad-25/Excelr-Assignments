# %%
# Creating a tuple with 3 student names
students = ("Rahul", "Anita", "Kiran")

print("Original tuple:", students)

# Trying to change the second name
students[1] = "Priya"
#Explenation
# Tuple is immutable it does not allow any kind of changes in it
# Out:
# Original tuple: ('Rahul', 'Anita', 'Kiran')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       4 print("Original tuple:", students)
#       6 # Trying to change the second name
# ----> 7 students[1] = "Priya"
#       8 #Explenation
#       9 # Tuple is immutable it does not allow any kind of changes in it
#
# TypeError: 'tuple' object does not support item assignment
