# %%
# Create the dictionary
person = {
    "name": "Amit",
    "age": 22,
    "city": "Bangalore"
}

# Update the age
person["age"] = 23

# Add a new key 'email'
person["email"] = "amit@example.com"

# Print the final dictionary
print("Final dictionary:", person)
# Out:
# Final dictionary: {'name': 'Amit', 'age': 23, 'city': 'Bangalore', 'email': 'amit@example.com'}
